# %% [markdown]
# # Feature Engineering and Scaling

# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd

# Load datasets
train_df = pd.read_csv("../datasets/UNSW_NB15_encoded_training-set.csv")
test_df = pd.read_csv("../datasets/UNSW_NB15_encoded_testing-set.csv")

# %%
# Overview of train_df
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 65 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ackdat             175341 non-null  float64
#  1   attack_cat         175341 non-null  int64
#  2   ct_dst_ltm         175341 non-null  int64
#  3   ct_dst_sport_ltm   175341 non-null  int64
#  4   ct_dst_src_ltm     175341 non-null  int64
#  5   ct_flw_http_mthd   175341 non-null  int64
#  6   ct_ftp_cmd         175341 non-null  int64
#  7   ct_src_dport_ltm   175341 non-null  int64
#  8   ct_src_ltm         175341 non-null  int64
#  9   ct_srv_dst         175341 non-null  int64
#  10  ct_srv_src         175341 non-null  int64
#  11  ct_state_ttl       175341 non-null  int64
#  12  dbytes             175341 non-null  int64
#  13  dinpkt             175341 non-null  float64
#  14  djit               175341 non-null  float64
#  15  dload              175341 non-null  float64
#  16  dloss              175341 non-null  int64
#  17  dmean              175341 non-null  int64
#  18  dpkts              175341 non-null  int64
#  19  dtcpb              175341 non-null  int64
#  20  dttl               175341 non-null  int64
#  21  dur                175341 non-null  float64
#  22  dwin               175341 non-null  int64
#  23  id                 175341 non-null  int64
#  24  is_ftp_login       175341 non-null  int64
#  25  is_sm_ips_ports    175341 non-null  int64
#  26  label              175341 non-null  int64
#  27  proto              175341 non-null  int64
#  28  rate               175341 non-null  float64
#  29  response_body_len  175341 non-null  int64
#  30  sbytes             175341 non-null  int64
#  31  service_dhcp       175341 non-null  bool
#  32  service_dns        175341 non-null  bool
#  33  service_ftp        175341 non-null  bool
#  34  service_ftp-data   175341 non-null  bool
#  35  service_http       175341 non-null  bool
#  36  service_irc        175341 non-null  bool
#  37  service_pop3       175341 non-null  bool
#  38  service_radius     175341 non-null  bool
#  39  service_smtp       175341 non-null  bool
#  40  service_snmp       175341 non-null  bool
#  41  service_ssh        175341 non-null  bool
#  42  service_ssl        175341 non-null  bool
#  43  sinpkt             175341 non-null  float64
#  44  sjit               175341 non-null  float64
#  45  sload              175341 non-null  float64
#  46  sloss              175341 non-null  int64
#  47  smean              175341 non-null  int64
#  48  spkts              175341 non-null  int64
#  49  state_CLO          175341 non-null  int64
#  50  state_CON          175341 non-null  int64
#  51  state_ECO          175341 non-null  bool
#  52  state_FIN          175341 non-null  bool
#  53  state_INT          175341 non-null  bool
#  54  state_PAR          175341 non-null  bool
#  55  state_REQ          175341 non-null  bool
#  56  state_RST          175341 non-null  bool
#  57  state_URN          175341 non-null  bool
#  58  state_no           175341 non-null  bool
#  59  stcpb              175341 non-null  int64
#  60  sttl               175341 non-null  int64
#  61  swin               175341 non-null  int64
#  62  synack             175341 non-null  float64
#  63  tcprtt             175341 non-null  float64
#  64  trans_depth        175341 non-null  int64
# dtypes: bool(20), float64(11), int64(34)
# memory usage: 63.5 MB

# %%
# Overview of test_df
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 65 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ackdat             82332 non-null  float64
#  1   attack_cat         82332 non-null  int64
#  2   ct_dst_ltm         82332 non-null  int64
#  3   ct_dst_sport_ltm   82332 non-null  int64
#  4   ct_dst_src_ltm     82332 non-null  int64
#  5   ct_flw_http_mthd   82332 non-null  int64
#  6   ct_ftp_cmd         82332 non-null  int64
#  7   ct_src_dport_ltm   82332 non-null  int64
#  8   ct_src_ltm         82332 non-null  int64
#  9   ct_srv_dst         82332 non-null  int64
#  10  ct_srv_src         82332 non-null  int64
#  11  ct_state_ttl       82332 non-null  int64
#  12  dbytes             82332 non-null  int64
#  13  dinpkt             82332 non-null  float64
#  14  djit               82332 non-null  float64
#  15  dload              82332 non-null  float64
#  16  dloss              82332 non-null  int64
#  17  dmean              82332 non-null  int64
#  18  dpkts              82332 non-null  int64
#  19  dtcpb              82332 non-null  int64
#  20  dttl               82332 non-null  int64
#  21  dur                82332 non-null  float64
#  22  dwin               82332 non-null  int64
#  23  id                 82332 non-null  int64
#  24  is_ftp_login       82332 non-null  int64
#  25  is_sm_ips_ports    82332 non-null  int64
#  26  label              82332 non-null  int64
#  27  proto              82332 non-null  int64
#  28  rate               82332 non-null  float64
#  29  response_body_len  82332 non-null  int64
#  30  sbytes             82332 non-null  int64
#  31  service_dhcp       82332 non-null  bool
#  32  service_dns        82332 non-null  bool
#  33  service_ftp        82332 non-null  bool
#  34  service_ftp-data   82332 non-null  bool
#  35  service_http       82332 non-null  bool
#  36  service_irc        82332 non-null  bool
#  37  service_pop3       82332 non-null  bool
#  38  service_radius     82332 non-null  bool
#  39  service_smtp       82332 non-null  bool
#  40  service_snmp       82332 non-null  bool
#  41  service_ssh        82332 non-null  bool
#  42  service_ssl        82332 non-null  bool
#  43  sinpkt             82332 non-null  float64
#  44  sjit               82332 non-null  float64
#  45  sload              82332 non-null  float64
#  46  sloss              82332 non-null  int64
#  47  smean              82332 non-null  int64
#  48  spkts              82332 non-null  int64
#  49  state_CLO          82332 non-null  bool
#  50  state_CON          82332 non-null  bool
#  51  state_ECO          82332 non-null  int64
#  52  state_FIN          82332 non-null  bool
#  53  state_INT          82332 non-null  bool
#  54  state_PAR          82332 non-null  int64
#  55  state_REQ          82332 non-null  bool
#  56  state_RST          82332 non-null  bool
#  57  state_URN          82332 non-null  int64
#  58  state_no           82332 non-null  int64
#  59  stcpb              82332 non-null  int64
#  60  sttl               82332 non-null  int64
#  61  swin               82332 non-null  int64
#  62  synack             82332 non-null  float64
#  63  tcprtt             82332 non-null  float64
#  64  trans_depth        82332 non-null  int64
# dtypes: bool(18), float64(11), int64(36)
# memory usage: 30.9 MB

# %%
# Create interaction features for train_df
train_df["sload_dload_product"] = train_df["sload"] * train_df["dload"]
train_df["sload_dload_ratio"] = train_df["sload"] / (train_df["dload"] + 1)
train_df["sload_dload_sum"] = train_df["sload"] + train_df["dload"]

# %%
# Create interaction features for test_df
test_df["sload_dload_product"] = test_df["sload"] * test_df["dload"]
test_df["sload_dload_ratio"] = test_df["sload"] / (test_df["dload"] + 1)
test_df["sload_dload_sum"] = test_df["sload"] + test_df["dload"]

# %% [markdown]
# **Log Transform Skewed Features**
#
# We have identified the highlt skewed data in `01_EDA.ipynb`. Now, we will use it!

# %%
high_skewed_features = [
    "trans_depth", "response_body_len", "sbytes", "sloss", "dloss", "spkts", 
    "dbytes", "dpkts", "dinpkt", "djit", "ct_flw_http_mthd", "sjit", 
    "sload", "dload", "sinpkt", "dur", "synack", "ackdat", "smean", 
    "rate", "dmean", "ct_src_dport_ltm", "ct_dst_ltm", "ct_src_ltm", 
    "ct_dst_sport_ltm", "ct_dst_src_ltm", "ct_srv_dst", "ct_srv_src", 
    "stcpb", "dtcpb"
]

# %%
import numpy as np

# Apply log1p transformation to all skewed features
for feature in high_skewed_features:
    if feature in train_df.columns:  # Ensure column exists in train_df
        train_df[feature] = np.log1p(train_df[feature])
    if feature in test_df.columns:  # Ensure column exists in test_df
        test_df[feature] = np.log1p(test_df[feature])

# %%
# Recalculate skewness
skewness_after = train_df[high_skewed_features].skew().sort_values(ascending=False)
print("Skewness After Transformation:")
print(skewness_after)
# Out:
# Skewness After Transformation:
# response_body_len    4.168025
# ct_flw_http_mthd     4.051059
# synack               3.432785
# ackdat               3.427472
# dur                  3.366384
# trans_depth          2.924598
# smean                2.029467
# dloss                1.786355
# sloss                1.376688
# sinpkt               1.240509
# ct_dst_sport_ltm     1.235297
# ct_src_dport_ltm     1.171539
# sbytes               1.169003
# spkts                1.116330
# dinpkt               0.901420
# djit                 0.847629
# ct_dst_ltm           0.845749
# dpkts                0.784531
# ct_src_ltm           0.654360
# ct_dst_src_ltm       0.631237
# ct_srv_dst           0.475789
# ct_srv_src           0.433191
# sjit                 0.430264
# dbytes               0.371869
# dload                0.314908
# dmean                0.218497
# dtcpb                0.208044
# stcpb                0.207972
# rate                -0.202975
# sload               -0.475929
# dtype: float64

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns
num_columns = train_df.select_dtypes(include=["float64", "int64"]).columns

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform train and test data
train_df[num_columns] = scaler.fit_transform(train_df[num_columns])
test_df[num_columns] = scaler.transform(test_df[num_columns])

# %%
train_df
# Out:
#           ackdat  attack_cat  ct_dst_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0      -0.528664   -0.126454   -0.958048         -0.641276       -1.064936
# 1      -0.528664   -0.126454   -0.958048         -0.641276       -0.654282
# 2       0.808064   -0.126454   -0.493499         -0.641276       -0.362918
# 3      -0.528664   -0.126454   -0.493499         -0.641276       -0.362918
# 4       0.983219   -0.126454   -0.493499         -0.641276        1.994143
# ...          ...         ...         ...               ...             ...
# 175336 -0.528664    0.740389    1.935725          1.717306        1.493116
# 175337  1.119340    1.607231   -0.958048         -0.641276       -0.654282
# 175338 -0.528664    0.740389   -0.163896          0.198868        0.905877
# 175339 -0.528664    0.740389    2.182182          1.800930        1.710980
# 175340 -0.528664    0.740389    2.182182          1.952636        1.710980
#
#         ct_flw_http_mthd  ct_ftp_cmd  ct_src_dport_ltm  ct_src_ltm  \
# 0              -0.312637   -0.118590         -0.713075   -1.093992
# 1              -0.312637   -0.118590         -0.713075   -1.093992
# 2              -0.312637   -0.118590         -0.713075   -0.630503
# 3              -0.312637    7.814915         -0.713075   -0.630503
# 4              -0.312637   -0.118590         -0.264706   -0.630503
# ...                  ...         ...               ...         ...
# 175336         -0.312637   -0.118590          2.079913    1.793180
# 175337         -0.312637   -0.118590         -0.713075   -1.093992
# 175338         -0.312637   -0.118590          0.053417   -0.301652
# 175339         -0.312637   -0.118590          2.317786    2.039075
# 175340         -0.312637   -0.118590          2.317786    2.039075
#
#         ct_srv_dst  ...  state_no     stcpb      sttl      swin    synack  \
# 0        -1.167162  ...     False  1.012541  0.703839  1.092456 -0.510116
# 1         0.128233  ...     False  1.090596 -1.141901  1.092456 -0.510116
# 2         0.128233  ...     False  1.128512 -1.141901  1.092456  1.011431
# 3        -1.167162  ...     False  1.067170 -1.141901  1.092456 -0.510116
# 4         1.930517  ...     False  1.141845  0.723268  1.092456  1.243236
# ...            ...  ...       ...       ...       ...       ...       ...
# 175336    1.444519  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175337   -1.167162  ...     False  1.176661  0.723268  1.092456  0.414154
# 175338    0.768339  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175339    1.666951  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175340    1.666951  ...     False -0.904695  0.723268 -0.915407 -0.510116
#
#           tcprtt  trans_depth  sload_dload_product  sload_dload_ratio  \
# 0      -0.521660    -0.334225            -0.238954          -0.388477
# 1      -0.521660    -0.334225            -0.237764          -0.388477
# 2       0.888444    -0.334225            -0.238961          -0.388477
# 3      -0.521660    -0.334225            -0.238986          -0.388477
# 4       1.096172    -0.334225            -0.238979          -0.388477
# ...          ...          ...                  ...                ...
# 175336 -0.521660    -0.334225            -0.238989          -0.119617
# 175337  0.731463    -0.334225            -0.238976          -0.388477
# 175338 -0.521660    -0.334225            -0.238989          -0.119617
# 175339 -0.521660    -0.334225            -0.238989          -0.119617
# 175340 -0.521660    -0.334225            -0.238989          -0.119617
#
#         sload_dload_sum
# 0             -0.393922
# 1             -0.391321
# 2             -0.393710
# 3             -0.394010
# 4             -0.393976
# ...                 ...
# 175336        -0.124703
# 175337        -0.393969
# 175338        -0.124703
# 175339        -0.124703
# 175340        -0.124703
#
# [175341 rows x 68 columns]

# %%
train_df
# Out:
#           ackdat  attack_cat  ct_dst_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0      -0.528664   -0.126454   -0.958048         -0.641276       -1.064936
# 1      -0.528664   -0.126454   -0.958048         -0.641276       -0.654282
# 2       0.808064   -0.126454   -0.493499         -0.641276       -0.362918
# 3      -0.528664   -0.126454   -0.493499         -0.641276       -0.362918
# 4       0.983219   -0.126454   -0.493499         -0.641276        1.994143
# ...          ...         ...         ...               ...             ...
# 175336 -0.528664    0.740389    1.935725          1.717306        1.493116
# 175337  1.119340    1.607231   -0.958048         -0.641276       -0.654282
# 175338 -0.528664    0.740389   -0.163896          0.198868        0.905877
# 175339 -0.528664    0.740389    2.182182          1.800930        1.710980
# 175340 -0.528664    0.740389    2.182182          1.952636        1.710980
#
#         ct_flw_http_mthd  ct_ftp_cmd  ct_src_dport_ltm  ct_src_ltm  \
# 0              -0.312637   -0.118590         -0.713075   -1.093992
# 1              -0.312637   -0.118590         -0.713075   -1.093992
# 2              -0.312637   -0.118590         -0.713075   -0.630503
# 3              -0.312637    7.814915         -0.713075   -0.630503
# 4              -0.312637   -0.118590         -0.264706   -0.630503
# ...                  ...         ...               ...         ...
# 175336         -0.312637   -0.118590          2.079913    1.793180
# 175337         -0.312637   -0.118590         -0.713075   -1.093992
# 175338         -0.312637   -0.118590          0.053417   -0.301652
# 175339         -0.312637   -0.118590          2.317786    2.039075
# 175340         -0.312637   -0.118590          2.317786    2.039075
#
#         ct_srv_dst  ...  state_no     stcpb      sttl      swin    synack  \
# 0        -1.167162  ...     False  1.012541  0.703839  1.092456 -0.510116
# 1         0.128233  ...     False  1.090596 -1.141901  1.092456 -0.510116
# 2         0.128233  ...     False  1.128512 -1.141901  1.092456  1.011431
# 3        -1.167162  ...     False  1.067170 -1.141901  1.092456 -0.510116
# 4         1.930517  ...     False  1.141845  0.723268  1.092456  1.243236
# ...            ...  ...       ...       ...       ...       ...       ...
# 175336    1.444519  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175337   -1.167162  ...     False  1.176661  0.723268  1.092456  0.414154
# 175338    0.768339  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175339    1.666951  ...     False -0.904695  0.723268 -0.915407 -0.510116
# 175340    1.666951  ...     False -0.904695  0.723268 -0.915407 -0.510116
#
#           tcprtt  trans_depth  sload_dload_product  sload_dload_ratio  \
# 0      -0.521660    -0.334225            -0.238954          -0.388477
# 1      -0.521660    -0.334225            -0.237764          -0.388477
# 2       0.888444    -0.334225            -0.238961          -0.388477
# 3      -0.521660    -0.334225            -0.238986          -0.388477
# 4       1.096172    -0.334225            -0.238979          -0.388477
# ...          ...          ...                  ...                ...
# 175336 -0.521660    -0.334225            -0.238989          -0.119617
# 175337  0.731463    -0.334225            -0.238976          -0.388477
# 175338 -0.521660    -0.334225            -0.238989          -0.119617
# 175339 -0.521660    -0.334225            -0.238989          -0.119617
# 175340 -0.521660    -0.334225            -0.238989          -0.119617
#
#         sload_dload_sum
# 0             -0.393922
# 1             -0.391321
# 2             -0.393710
# 3             -0.394010
# 4             -0.393976
# ...                 ...
# 175336        -0.124703
# 175337        -0.393969
# 175338        -0.124703
# 175339        -0.124703
# 175340        -0.124703
#
# [175341 rows x 68 columns]

# %%
# Save preprocessed data for later sections
train_df.to_csv("../datasets/UNSW_NB15_preprocessed_training-set.csv", index=False)
test_df.to_csv("../datasets/UNSW_NB15_preprocessed_testing-set.csv", index=False)
