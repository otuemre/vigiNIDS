# %% [markdown]
# # Modelling

# %% [markdown]
# ## Get the Data Ready

# %%
# Imports
import pandas as pd

train_df = pd.read_csv("../datasets/UNSW_NB15_preprocessed_training-set.csv")
test_df = pd.read_csv("../datasets/UNSW_NB15_preprocessed_testing-set.csv")

# %%
train_df.head()
# Out:
#      ackdat  attack_cat  ct_dst_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0 -0.528664           1   -0.958048         -0.641276       -1.064936
# 1 -0.528664           1   -0.958048         -0.641276       -0.654282
# 2  0.808064           1   -0.493499         -0.641276       -0.362918
# 3 -0.528664           1   -0.493499         -0.641276       -0.362918
# 4  0.983219           1   -0.493499         -0.641276        1.994143
#
#    ct_flw_http_mthd  ct_ftp_cmd  ct_src_dport_ltm  ct_src_ltm  ct_srv_dst  \
# 0         -0.312637   -0.118590         -0.713075   -1.093992   -1.167162
# 1         -0.312637   -0.118590         -0.713075   -1.093992    0.128233
# 2         -0.312637   -0.118590         -0.713075   -0.630503    0.128233
# 3         -0.312637    7.814915         -0.713075   -0.630503   -1.167162
# 4         -0.312637   -0.118590         -0.264706   -0.630503    1.930517
#
#    ...  state_REQ  state_RST  state_URN  state_no     stcpb      sttl  \
# 0  ...      False      False      False     False  1.012541  0.703839
# 1  ...      False      False      False     False  1.090596 -1.141901
# 2  ...      False      False      False     False  1.128512 -1.141901
# 3  ...      False      False      False     False  1.067170 -1.141901
# 4  ...      False      False      False     False  1.141845  0.723268
#
#        swin    synack    tcprtt  trans_depth
# 0  1.092456 -0.510116 -0.521660    -0.334225
# 1  1.092456 -0.510116 -0.521660    -0.334225
# 2  1.092456  1.011431  0.888444    -0.334225
# 3  1.092456 -0.510116 -0.521660    -0.334225
# 4  1.092456  1.243236  1.096172    -0.334225
#
# [5 rows x 68 columns]

# %%
train_df.columns, len(train_df.columns)
# Out:
# (Index(['ackdat', 'attack_cat', 'ct_dst_ltm', 'ct_dst_sport_ltm',
#         'ct_dst_src_ltm', 'ct_flw_http_mthd', 'ct_ftp_cmd', 'ct_src_dport_ltm',
#         'ct_src_ltm', 'ct_srv_dst', 'ct_srv_src', 'ct_state_ttl', 'dbytes',
#         'dinpkt', 'djit', 'dload', 'dloss', 'dmean', 'dpkts', 'dtcpb', 'dttl',
#         'dur', 'dwin', 'id', 'is_ftp_login', 'is_sm_ips_ports', 'label',
#         'proto', 'rate', 'response_body_len', 'sbytes', 'service_dhcp',
#         'service_dns', 'service_ftp', 'service_ftp-data', 'service_http',
#         'service_irc', 'service_pop3', 'service_radius', 'service_smtp',
#         'service_snmp', 'service_ssh', 'service_ssl', 'sinpkt', 'sjit', 'sload',
#         'sload_dload_product', 'sload_dload_ratio', 'sload_dload_sum', 'sloss',
#         'smean', 'spkts', 'state_CLO', 'state_CON', 'state_ECO', 'state_FIN',
#         'state_INT', 'state_PAR', 'state_REQ', 'state_RST', 'state_URN',
#         'state_no', 'stcpb', 'sttl', 'swin', 'synack', 'tcprtt', 'trans_depth'],
#        dtype='object'),
#  68)

# %%
test_df.head()
# Out:
#      ackdat  attack_cat  ct_dst_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0 -0.528664           1   -0.958048         -0.641276       -0.654282
# 1 -0.528664           1   -0.958048         -0.641276       -0.654282
# 2 -0.528664           1   -0.958048         -0.641276       -0.362918
# 3 -0.528664           1   -0.493499         -0.641276       -0.362918
# 4 -0.528664           1   -0.493499         -0.641276       -0.362918
#
#    ct_flw_http_mthd  ct_ftp_cmd  ct_src_dport_ltm  ct_src_ltm  ct_srv_dst  \
# 0         -0.312637    -0.11859         -0.713075   -1.093992   -0.747899
# 1         -0.312637    -0.11859         -0.713075   -1.093992   -0.747899
# 2         -0.312637    -0.11859         -0.713075   -1.093992   -0.450427
# 3         -0.312637    -0.11859         -0.264706   -0.630503   -0.450427
# 4         -0.312637    -0.11859         -0.264706   -0.630503   -0.450427
#
#    ...  state_REQ  state_RST  state_URN  state_no     stcpb      sttl  \
# 0  ...      False      False          0         0 -0.904695  0.723268
# 1  ...      False      False          0         0 -0.904695  0.723268
# 2  ...      False      False          0         0 -0.904695  0.723268
# 3  ...      False      False          0         0 -0.904695  0.723268
# 4  ...      False      False          0         0 -0.904695  0.723268
#
#        swin    synack   tcprtt  trans_depth
# 0 -0.915407 -0.510116 -0.52166    -0.334225
# 1 -0.915407 -0.510116 -0.52166    -0.334225
# 2 -0.915407 -0.510116 -0.52166    -0.334225
# 3 -0.915407 -0.510116 -0.52166    -0.334225
# 4 -0.915407 -0.510116 -0.52166    -0.334225
#
# [5 rows x 68 columns]

# %%
test_df.columns, len(test_df.columns)
# Out:
# (Index(['ackdat', 'attack_cat', 'ct_dst_ltm', 'ct_dst_sport_ltm',
#         'ct_dst_src_ltm', 'ct_flw_http_mthd', 'ct_ftp_cmd', 'ct_src_dport_ltm',
#         'ct_src_ltm', 'ct_srv_dst', 'ct_srv_src', 'ct_state_ttl', 'dbytes',
#         'dinpkt', 'djit', 'dload', 'dloss', 'dmean', 'dpkts', 'dtcpb', 'dttl',
#         'dur', 'dwin', 'id', 'is_ftp_login', 'is_sm_ips_ports', 'label',
#         'proto', 'rate', 'response_body_len', 'sbytes', 'service_dhcp',
#         'service_dns', 'service_ftp', 'service_ftp-data', 'service_http',
#         'service_irc', 'service_pop3', 'service_radius', 'service_smtp',
#         'service_snmp', 'service_ssh', 'service_ssl', 'sinpkt', 'sjit', 'sload',
#         'sload_dload_product', 'sload_dload_ratio', 'sload_dload_sum', 'sloss',
#         'smean', 'spkts', 'state_CLO', 'state_CON', 'state_ECO', 'state_FIN',
#         'state_INT', 'state_PAR', 'state_REQ', 'state_RST', 'state_URN',
#         'state_no', 'stcpb', 'sttl', 'swin', 'synack', 'tcprtt', 'trans_depth'],
#        dtype='object'),
#  68)

# %%
# Create X and y and drop id
X_train = train_df.drop(columns=["id", "label", "attack_cat"])
y_train = train_df["label"]

X_test = test_df.drop(columns=["id", "label", "attack_cat"])
y_test = test_df["label"]

# %% [markdown]
# **Note**: During my experiments, I have reliazed the `attack_cat` is highly relevant for `label` which makes the model a perfect model with %100. It shouldn't be the case as this is a real-world dataset. Therefore, I have decided to drop `attack_cat` for a better model. My aim to have %90-%95 accuracy!

# %%
X_train.columns
# Out:
# Index(['ackdat', 'ct_dst_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'ct_flw_http_mthd', 'ct_ftp_cmd', 'ct_src_dport_ltm', 'ct_src_ltm',
#        'ct_srv_dst', 'ct_srv_src', 'ct_state_ttl', 'dbytes', 'dinpkt', 'djit',
#        'dload', 'dloss', 'dmean', 'dpkts', 'dtcpb', 'dttl', 'dur', 'dwin',
#        'is_ftp_login', 'is_sm_ips_ports', 'proto', 'rate', 'response_body_len',
#        'sbytes', 'service_dhcp', 'service_dns', 'service_ftp',
#        'service_ftp-data', 'service_http', 'service_irc', 'service_pop3',
#        'service_radius', 'service_smtp', 'service_snmp', 'service_ssh',
#        'service_ssl', 'sinpkt', 'sjit', 'sload', 'sload_dload_product',
#        'sload_dload_ratio', 'sload_dload_sum', 'sloss', 'smean', 'spkts',
#        'state_CLO', 'state_CON', 'state_ECO', 'state_FIN', 'state_INT',
#        'state_PAR', 'state_REQ', 'state_RST', 'state_URN', 'state_no', 'stcpb',
#        'sttl', 'swin', 'synack', 'tcprtt', 'trans_depth'],
#       dtype='object')

# %% [markdown]
# ## XGBoost

# %%
y_train
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 175336    1
# 175337    1
# 175338    1
# 175339    1
# 175340    1
# Name: label, Length: 175341, dtype: int64

# %%
from xgboost import XGBClassifier
import xgboost as xgb

xgb_model = XGBClassifier(tree_method="hist", device="cuda", verbosity=2)
xgb_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\base.py:469, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     467 output = {"text/plain": repr(self)}
#     468 if get_config()["display"] == "diagram":
# --> 469     output["text/html"] = estimator_html_repr(self)
#     470 return output
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\base.py:463, in BaseEstimator._repr_html_inner(self)
#     458 def _repr_html_inner(self):
#     459     """This function is returned by the @property `_repr_html_` to make
#     460     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     461     on `get_config()["display"]`.
#     462     """
# --> 463     return estimator_html_repr(self)
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File ~\PycharmProjects\vigiNIDS\.venv\lib\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_model.score(X_test, y_test)
# Out:
# C:\Users\emrev\PycharmProjects\vigiNIDS\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [19:15:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# 0.8721274838458922

# %%
import matplotlib.pyplot as plt

# Plot Feature Importance
xgb.plot_importance(xgb_model, max_num_features=10)

# Save the image
plt.savefig("../images/xgboost_base_feature_importance.png")

# Show the plot
plt.show()

# %%
# Import our custom function from ./src/utils/print_unique_values.py
import sys
import os
from pathlib import Path

# Get the current notebook's directory
notebook_dir = Path.cwd()

# Add the src directory to the sys.path
sys.path.append(str(notebook_dir.parent))  # Go up one level from notebooks

# Import the function
from utils.evaluate_classification import evaluate_classification
from utils.plot_auc_roc import plot_auc_roc
from utils.plot_confusion_matrix import plot_confusion_matrix

# %%
# Predict labels and probabilities
y_pred = xgb_model.predict(X_test)
y_proba = xgb_model.predict_proba(X_test)[:, 1]

# %%
# Get evaluation metrics
metrics = evaluate_classification(y_test, y_pred)
print("Evaluation Metrics:")
metrics
# Out:
# Evaluation Metrics:
# {'Accuracy': 0.8721274838458922,
#  'Precision': 0.8231209150326797,
#  'Recall': 0.9778964087179035,
#  'F1 Score': 0.8938581279993547,
#  'Confusion Matrix': array([[27474,  9526],
#         [ 1002, 44330]], dtype=int64)}

# %%
# Plot the confusion matrix
plot_confusion_matrix(y_test, y_pred, class_names=["Normal", "Attack"])

# %% [markdown]
# **Insigth**: It seems that the model is confused when the truth label is `normal`. It is probably the imbalance of train_df. As we see on EDA section, there were a lot more attack than normal. However, it might be beneficial as this system requires high attention. Instead of labelling an `attack` as `normal`, labelling `normal` as `attack` is better. Even though `recall` is more important for these type of systems, I will try to improve `precision` as well.

# %%
# Plot AUC-ROC
auc = plot_auc_roc(y_test, y_proba)
print(f"AUC: {auc:.4f}")
# Out:
# AUC: 0.9823

# %% [markdown]
# ## LightGBM

# %%
from lightgbm import LGBMClassifier

lgbm_model = LGBMClassifier(device="gpu")
lgbm_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 119341, number of negative: 56000
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 6932
# [LightGBM] [Info] Number of data points in the train set: 175341, number of used features: 58
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 4060 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 39 dense feature groups (6.69 MB) transferred to GPU in 0.007071 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.680622 -> initscore=0.756633
# [LightGBM] [Info] Start training from score 0.756633
# LGBMClassifier(device='gpu')

# %%
lgbm_model.score(X_test, y_test)
# Out:
# 0.8763056891609581

# %%
import matplotlib.pyplot as plt
import lightgbm as lgbm

# Plot Feature Importance
lgbm.plot_importance(lgbm_model, max_num_features=10)

# Save the image
plt.savefig("../images/lightgbm_base_feature_importance.png")

# Show the plot
plt.show()

# %%
# Predict labels and probabilities
y_pred = lgbm_model.predict(X_test)
y_proba = lgbm_model.predict_proba(X_test)[:, 1]

# %%
# Get evaluation metrics
metrics = evaluate_classification(y_test, y_pred)
print("Evaluation Metrics:")
metrics
# Out:
# Evaluation Metrics:
# {'Accuracy': 0.8763056891609581,
#  'Precision': 0.8243752076488612,
#  'Recall': 0.9852422130062649,
#  'F1 Score': 0.897658526781228,
#  'Confusion Matrix': array([[27485,  9515],
#         [  669, 44663]], dtype=int64)}

# %%
# Plot the confusion matrix
plot_confusion_matrix(y_test, y_pred, class_names=["Normal", "Attack"])

# %%
# Plot AUC-ROC
auc = plot_auc_roc(y_test, y_proba)
print(f"AUC: {auc:.4f}")
# Out:
# AUC: 0.9863

# %% [markdown]
# **Insight**: It seems that LightGBM model's performance is slightly higher.

# %% [markdown]
# ## CatBoost

# %%
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(iterations=1000, task_type="GPU", devices='0', verbose=0)

catboost_model.fit(X_train, y_train)

# %%
catboost_model.score(X_test, y_test)
# Out:
# 0.8724554243793422

# %%
# Predict labels and probabilities
y_pred = lgbm_model.predict(X_test)
y_proba = lgbm_model.predict_proba(X_test)[:, 1]

# %%
# Get evaluation metrics
metrics = evaluate_classification(y_test, y_pred)
print("Evaluation Metrics:")
metrics
# Out:
# Evaluation Metrics:
# {'Accuracy': 0.8763056891609581,
#  'Precision': 0.8243752076488612,
#  'Recall': 0.9852422130062649,
#  'F1 Score': 0.897658526781228,
#  'Confusion Matrix': array([[27485,  9515],
#         [  669, 44663]], dtype=int64)}

# %%
# Plot the confusion matrix
plot_confusion_matrix(y_test, y_pred, class_names=["Normal", "Attack"])

# %%
# Plot AUC-ROC
auc = plot_auc_roc(y_test, y_proba)
print(f"AUC: {auc:.4f}")
# Out:
# AUC: 0.9863

# %% [markdown]
# ## TabNet

# %%
# Convert boolean to int
train_bool_columns = X_train.select_dtypes(include=["bool"]).columns
test_bool_columns = X_test.select_dtypes(include=["bool"]).columns

X_train[train_bool_columns] = X_train[train_bool_columns].astype(int)
X_test[test_bool_columns] = X_test[test_bool_columns].astype(int)

# %%
X_train.select_dtypes(include=["bool"]).columns
# Out:
# Index([], dtype='object')

# %%
X_test.select_dtypes(include=["bool"]).columns
# Out:
# Index([], dtype='object')

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import numpy as np

# Convert data to tensors
X_train_np = X_train.values.astype("float32")  # Ensure float32 dtype
y_train_np = y_train.values.astype("int64")  # Ensure int64 dtype

X_test_np = X_test.values.astype("float32")
y_test_np = y_test.values.astype("int64")

tabnet_model = TabNetClassifier(device_name="cuda")
tabnet_model.fit(X_train_np, y_train_np, eval_set=[(X_test_np, y_test_np)])
# Out:
# C:\Users\emrev\PycharmProjects\vigiNIDS\.venv\lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.23096 | val_0_auc: 0.95254 |  0:00:08s
# epoch 1  | loss: 0.14061 | val_0_auc: 0.95825 |  0:00:16s
# epoch 2  | loss: 0.12975 | val_0_auc: 0.97275 |  0:00:24s
# epoch 3  | loss: 0.12383 | val_0_auc: 0.95214 |  0:00:32s
# epoch 4  | loss: 0.12179 | val_0_auc: 0.94347 |  0:00:40s
# epoch 5  | loss: 0.1205  | val_0_auc: 0.91454 |  0:00:49s
# epoch 6  | loss: 0.11855 | val_0_auc: 0.97659 |  0:00:57s
# epoch 7  | loss: 0.11878 | val_0_auc: 0.97735 |  0:01:06s
# epoch 8  | loss: 0.11709 | val_0_auc: 0.95761 |  0:01:15s
# epoch 9  | loss: 0.1171  | val_0_auc: 0.941   |  0:01:23s
# epoch 10 | loss: 0.11589 | val_0_auc: 0.93739 |  0:01:32s
# epoch 11 | loss: 0.11568 | val_0_auc: 0.92508 |  0:01:41s
# epoch 12 | loss: 0.11593 | val_0_auc: 0.93205 |  0:01:49s
# epoch 13 | loss: 0.12058 | val_0_auc: 0.97539 |  0:01:58s
# epoch 14 | loss: 0.12156 | val_0_auc: 0.97293 |  0:02:07s
# epoch 15 | loss: 0.11568 | val_0_auc: 0.97763 |  0:02:14s
# epoch 16 | loss: 0.11462 | val_0_auc: 0.97826 |  0:02:21s
# epoch 17 | loss: 0.11338 | val_0_auc: 0.97212 |  0:02:29s
# epoch 18 | loss: 0.11275 | val_0_auc: 0.9502  |  0:02:36s
# epoch 19 | loss: 0.11137 | val_0_auc: 0.94125 |  0:02:43s
# epoch 20 | loss: 0.11188 | val_0_auc: 0.91657 |  0:02:50s
# epoch 21 | loss: 0.11372 | val_0_auc: 0.94359 |  0:02:58s
# epoch 22 | loss: 0.11175 | val_0_auc: 0.94374 |  0:03:05s
# epoch 23 | loss: 0.11313 | val_0_auc: 0.97573 |  0:03:13s
# epoch 24 | loss: 0.11247 | val_0_auc: 0.97995 |  0:03:20s
# epoch 25 | loss: 0.11062 | val_0_auc: 0.94556 |  0:03:27s
# epoch 26 | loss: 0.11075 | val_0_auc: 0.95234 |  0:03:33s
# epoch 27 | loss: 0.11105 | val_0_auc: 0.94984 |  0:03:40s
# epoch 28 | loss: 0.11122 | val_0_auc: 0.95516 |  0:03:47s
# epoch 29 | loss: 0.11085 | val_0_auc: 0.94916 |  0:03:54s
# epoch 30 | loss: 0.11066 | val_0_auc: 0.94929 |  0:04:01s
# epoch 31 | loss: 0.10921 | val_0_auc: 0.95262 |  0:04:09s
# epoch 32 | loss: 0.10876 | val_0_auc: 0.94741 |  0:04:17s
# epoch 33 | loss: 0.10881 | val_0_auc: 0.94744 |  0:04:24s
# epoch 34 | loss: 0.10805 | val_0_auc: 0.94717 |  0:04:33s
#
# Early stopping occurred at epoch 34 with best_epoch = 24 and best_val_0_auc = 0.97995
# C:\Users\emrev\PycharmProjects\vigiNIDS\.venv\lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
y_pred = tabnet_model.predict(X_test_np)
y_proba = tabnet_model.predict_proba(X_test_np)[:, 1]

# %%
# Get evaluation metrics
metrics = evaluate_classification(y_test_np, y_pred)
print("Evaluation Metrics:")
metrics
# Out:
# Evaluation Metrics:
# {'Accuracy': 0.8745080891998251,
#  'Precision': 0.8260545535847369,
#  'Recall': 0.978028765551928,
#  'F1 Score': 0.8956405801785786,
#  'Confusion Matrix': array([[27664,  9336],
#         [  996, 44336]], dtype=int64)}

# %%
# Plot the confusion matrix
plot_confusion_matrix(y_test_np, y_pred, class_names=["Normal", "Attack"])

# %%
# Plot AUC-ROC
auc = plot_auc_roc(y_test_np, y_proba)
print(f"AUC: {auc:.4f}")
# Out:
# AUC: 0.9800

# %% [markdown]
# **Insight**: The `TabNet` is better in terms of accuracy. However, the recall and AUC lowered a bit.
